# %%
output = """
Plane Admin Plane    up->dn  up->mcast
Id    State State    counter   counter
--------------------------------------
0     UP    UP             7         7 
1     UP    UP             7         7 
2     UP    UP             7         7 
3     UP    UP             7         7 
4     UP    UP             5         7 
5     UP    UP             5         7 
6     UP    UP             5         7 
7     UP    UP             5         7 
"""

if output.count('UP') == 18:
	print ('this is test')

# %%
# Input lists
input_list1 = [[[[7]]], [[1, 2], [3, 4], [[[9]]]]]
input_list2 = [1, 2, 3, [[[[7]]]], [[1, 2]], [[1, 2], [3, 4], [[7]]]]

def flatten(input_list, flat_list):
    # Iterate through each element in the input list
    for element in input_list:
        # Check if the element is a list
        if isinstance(element, list):
            # Recursively flatten the sublist
            flatten(element, flat_list)
        else:
            # If it's not a list, add it to the flat_list
            flat_list.append(element)

# Create empty lists to store the flattened elements
flat_list1 = []
flat_list2 = []

# Call the function to flatten each input list
flatten(input_list1, flat_list1)
flatten(input_list2, flat_list2)

# Print the output lists
print("Flattened list 1:", flat_list1)
print("Flattened list 2:", flat_list2)
# Out:
# Flattened list 1: [7, 1, 2, 3, 4, 9]
# Flattened list 2: [1, 2, 3, 7, 1, 2, 1, 2, 3, 4, 7]

# %%
output = """
Wed Mar 13 00:45:28.192 PDT
Capability codes:
        (R) Router, (B) Bridge, (T) Telephone, (C) DOCSIS Cable Device
        (W) WLAN Access Point, (P) Repeater, (S) Station, (O) Other

Device ID                                 Local Intf                       Hold-time Capability Port ID             
D8W                                       FourHundredGigE0/2/0/1           120       R          Bundle-Ether28100   
D8W                                       FourHundredGigE0/2/0/1           120       R          FourHundredGigE0/7/0/1
D8WAN.network.cisco.com                   FourHundredGigE0/2/0/2           120       R          FourHundredGigE0/4/0/9
D8WAN.network.cisco.com                   FourHundredGigE0/2/0/2           120       R          Bundle-Ether28008   
D8W                                       FourHundredGigE0/2/0/5           120       R          Bundle-Ether28104   
D8W                                       FourHundredGigE0/2/0/5           120       R          FourHundredGigE0/7/0/5
D8W                                       FourHundredGigE0/2/0/6           120       R          Bundle-Ether28105   
D8W                                       FourHundredGigE0/2/0/6           120       R          FourHundredGigE0/7/0/6
D8W                                       FourHundredGigE0/2/0/7           120       R          Bundle-Ether28106   
D8W                                       FourHundredGigE0/2/0/7           120       R          FourHundredGigE0/7/0/7
D8W                                       FourHundredGigE0/2/0/8           120       R          Bundle-Ether28107   
D8W                                       FourHundredGigE0/2/0/8           120       R          FourHundredGigE0/7/0/8
D8W                                       FourHundredGigE0/2/0/9           120       R          Bundle-Ether28108   
D8W                                       FourHundredGigE0/2/0/9           120       R          FourHundredGigE0/7/0/9
D8W2.network.cisco.com                    FourHundredGigE0/2/0/10          120       R          Bundle-Ether28200   
D8W2.network.cisco.com                    FourHundredGigE0/2/0/10          120       R          FourHundredGigE0/6/0/10
D8W2.network.cisco.com                    FourHundredGigE0/2/0/11          120       R          Bundle-Ether28201   
D8W2.network.cisco.com                    FourHundredGigE0/2/0/11          120       R          FourHundredGigE0/6/0/11  
D8W2.network.cisco.com                    FourHundredGigE0/2/0/13          120       R          FourHundredGigE0/6/0/13
D8W2.network.cisco.com                    FourHundredGigE0/2/0/14          120       R          Bundle-Ether28203   
D8W2.network.cisco.com                    FourHundredGigE0/2/0/14          120       R          FourHundredGigE0/6/0/14
D8W2.network.cisco.com                    FourHundredGigE0/2/0/15          120       R          Bundle-Ether28204   
D8W2.network.cisco.com                    FourHundredGigE0/2/0/15          120       R          FourHundredGigE0/6/0/15
D8W2.network.cisco.com                    FourHundredGigE0/2/0/16          120       R          Bundle-Ether28205   
D8W2.network.cisco.com                    FourHundredGigE0/2/0/16          120       R          FourHundredGigE0/6/0/16
D8W2.network.cisco.com                    FourHundredGigE0/2/0/17          120       R          Bundle-Ether28206   
D8W2.network.cisco.com                    FourHundredGigE0/2/0/17          120       R          FourHundredGigE0/6/0/17
"""
n = "FourHundredGigE0/2/0/13"
# Split the output by lines
#output_lines = output.split('\n')
#output_lines = output.splitlines()
output_lines = output.strip().splitlines()
#print(output_lines)

# Find the line containing the interface information
interface_line = ""
for line in output_lines:
    if n in line:
        interface_line = line
        break
#print (interface_line)
# Extract device ID and port ID
device_id = interface_line.split()[0]
port_id = interface_line.split()[-1]

print("Device ID:", device_id)
print("Port ID:", port_id)


# lines = output.strip().splitlines()
# #print(lines[6:])

# n = "FourHundredGigE0/2/0/13"
# for line in lines[6:]:
#     parts = line.split()
#     #print(parts)
#     device_id = parts[0]
#     neighbor_id = parts[-1]
#     local_intf = parts[1]

#     if n in local_intf:
#         print (device_id )
#         print (neighbor_id)
# Out:
# Device ID: D8W2.network.cisco.com
# Port ID: FourHundredGigE0/6/0/13

# %%
output = """
Sat Jul  6 02:06:50.525 PDT

HundredGigE0/12/0/34 output: P_SHAPER

Class class-default
  Classification statistics          (packets/bytes)     (rate - kbps)
    Matched             :         39495844297/81473883913699       59282892
    Transmitted         :         39495844297/81473883913699       59282892
    Total Dropped       :                   0/0                    0

  Policy QOS_QUEUEING Class TC7_Control_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :               36505/52801979             2
      Transmitted         :               36505/52801979             2
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20375 
      Taildropped(packets/bytes)           : 0/0

  Policy QOS_QUEUEING Class TC6_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :                   0/0                    0
      Transmitted         :                   0/0                    0
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20374 
      Taildropped(packets/bytes)           : 0/0

  Policy QOS_QUEUEING Class PERFISO_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :                   0/0                    0
      Transmitted         :                   0/0                    0
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20373 
      Taildropped(packets/bytes)           : 0/0

  Policy QOS_QUEUEING Class RDMA_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :         26817317053/27460932663161       20091633
      Transmitted         :         26817317053/27460932663161       20091633
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20372 
      Taildropped(packets/bytes)           : 0/0

      WRED profile for 
      RED Transmitted (packets/bytes)            : N/A
      RED random drops(packets/bytes)            : N/A 
      RED maxthreshold drops(packets/bytes)      : N/A 
      RED ecn marked & transmitted(packets/bytes): 0/0

  Policy QOS_QUEUEING Class LOSSLESSTCP_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :          9719131368/27386063481755       19925636
      Transmitted         :          9719131368/27386063481755       19925636
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20371 
      Taildropped(packets/bytes)           : 0/0

      WRED profile for 
      RED Transmitted (packets/bytes)            : N/A
      RED random drops(packets/bytes)            : N/A 
      RED maxthreshold drops(packets/bytes)      : N/A 
      RED ecn marked & transmitted(packets/bytes): 0/0

  Policy QOS_QUEUEING Class SCAVENGER_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :                   0/0                    0
      Transmitted         :                   0/0                    0
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20370 
      Taildropped(packets/bytes)           : 0/0

  Policy QOS_QUEUEING Class VOIP_Egress
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :                   0/0                    0
      Transmitted         :                   0/0                    0
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20369 
      Taildropped(packets/bytes)           : 0/0

  Policy QOS_QUEUEING Class class-default
    Classification statistics          (packets/bytes)     (rate - kbps)
      Matched             :          2959359371/26626834966804       19265621
      Transmitted         :          2959359371/26626834966804       19265621
      Total Dropped       :                   0/0                    0
    Queueing statistics
      Queue ID                             : 20368 
      Taildropped(packets/bytes)           : 0/0
"""


lines = output.split('\n')
desired_lines = []
for line in lines:
    if line.strip().startswith("Policy") or line.strip().startswith("Class class-default"):
        desired_lines.append(line.strip())
print(f"List of Class and Policy Map = {desired_lines}")
# Out:
# List of Class and Policy Map = ['Class class-default', 'Policy QOS_QUEUEING Class TC7_Control_Egress', 'Policy QOS_QUEUEING Class TC6_Egress', 'Policy QOS_QUEUEING Class PERFISO_Egress', 'Policy QOS_QUEUEING Class RDMA_Egress', 'Policy QOS_QUEUEING Class LOSSLESSTCP_Egress', 'Policy QOS_QUEUEING Class SCAVENGER_Egress', 'Policy QOS_QUEUEING Class VOIP_Egress', 'Policy QOS_QUEUEING Class class-default']

# %%
# Sample output string
output = """
# show ip interface brief

Interface          IP Address      Subnet Mask     Status     Protocol
-------------------------------------------------------------------------
mgmt0              192.168.1.100   255.255.255.0   up         up
eth0               10.0.0.1        255.255.255.0   up         up
eth1               10.0.1.1        255.255.255.0   down       down
eth2               192.168.10.1    255.255.255.0   up         down
eth3               192.168.20.1    255.255.255.0   up         up
"""

# Split the output into lines
lines = output.strip().splitlines()
print(lines)

# Initialize a list to store the matching interfaces
matching_interfaces = []

# Iterate over each line after the header
for line in lines[4:]:  # Skip the first three lines (header)
    parts = line.split()
    print (parts)
    
    # Extract relevant columns
    interface = parts[0]
    status = parts[3]
    protocol = parts[-1]
    
    # Check if the status is "up" and protocol is "down"
    if status == "up" and protocol == "down":
        matching_interfaces.append(interface)
# Print the result
print("Interfaces with status 'up' and protocol 'down':")
for intf in matching_interfaces:
    print(intf)
# Out:
# ['# show ip interface brief', '', 'Interface          IP Address      Subnet Mask     Status     Protocol', '-------------------------------------------------------------------------', 'mgmt0              192.168.1.100   255.255.255.0   up         up', 'eth0               10.0.0.1        255.255.255.0   up         up', 'eth1               10.0.1.1        255.255.255.0   down       down', 'eth2               192.168.10.1    255.255.255.0   up         down', 'eth3               192.168.20.1    255.255.255.0   up         up']
# ['mgmt0', '192.168.1.100', '255.255.255.0', 'up', 'up']
# ['eth0', '10.0.0.1', '255.255.255.0', 'up', 'up']
# ['eth1', '10.0.1.1', '255.255.255.0', 'down', 'down']
# ['eth2', '192.168.10.1', '255.255.255.0', 'up', 'down']
# ['eth3', '192.168.20.1', '255.255.255.0', 'up', 'up']
# Interfaces with status 'up' and protocol 'down':
# eth2

# %%
# Find the number of prefixed received for each neighbor

output = """
Fri Jul  5 01:23:14.843 PDT
BGP router identifier 100.250.112.99, local AS number 116536
BGP generic scan interval 60 secs
Non-stop routing is enabled
Table ID: 0xe0000000   RD version: 3025733855
BGP table nexthop route policy: 
BGP main routing table version 3025733855
BGP NSR Initial initsync version 3872894 (Reached)
BGP NSR/ISSU Sync-Group versions 3025282092/0
BGP scan interval 60 secs

BGP is operating in STANDALONE mode.


Process    RcvTblVer     bRIB/RIB     LabelVer    ImportVer    SendTblVer   StandbyVer
Speaker   3025734288    3025282092    3025282092    3025282092    3025282092    3025282092

Neighbor        Spk    AS MsgRcvd MsgSent       TblVer  InQ OutQ  Up/Down  St/PfxRcd
100.250.104.99    0 116536  249524  250131   3025282092    0    0 17:43:08          0
100.250.202.99    0 116536  250471  251043   3025282092    0    0    6d11h          0
100.250.204.99    0 116536  250626  251182   3025282092    0    0     1w0d          0
100.250.208.99    0 116536 8711833  332587   3025282092    0    0     1w1d       1691
100.250.209.99    0 116536 9156046  332578   3025282092    0    0     1w1d       1691
101.52.0.0        0 130537   23922   22671   3025282092    0    0 06:44:28        100
101.52.0.2        0 130537   23927   22667   3025282092    0    0 06:44:11        100
101.62.0.0        0 130537  190346   25101   3025282092   48    0     1w1d      39950
101.62.0.2        0 130537  190411   25101   3025282092    0    0     1w1d      78440
101.62.0.4        0 130537  190353   25101   3025282092   48    0     1w1d      39950
101.62.0.6        0 130537  190400   25099   3025282092    0    0     1w1d      78440
101.62.0.8        0 130537  190424   25101   3025282092    0    0     1w1d      78440
101.62.0.10       0 130537  190346   25101   3025282092   48    0     1w1d      39950
101.62.0.12       0 130537  190355   25101   3025282092   48    0     1w1d      39950
101.62.0.14       0 130537  190386   25101   3025282092   20    0     1w1d      62096
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.0 = Counter64: 1692787
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.1 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.2 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.3 = Counter64: 260449646
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.4 = Counter64: 260446553
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.5 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.6 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.7 = Counter64: 0
"""

# # Split the output into lines
# lines = output.splitlines()

# # Flag to indicate when to start parsing neighbor data
# parse_flag = 0

# # Loop through the lines and extract neighbor data
# for line in lines:
#   # Check for header line first (more specific condition)
#   if "Neighbor        Spk    AS MsgRcvd MsgSent       TblVer  InQ OutQ  Up/Down  St/PfxRcd" in line:
#     parse_flag = 1
#   # Process neighbor data if flag is set
#   elif parse_flag == 1:
#     # Split the line by whitespace (considering multiple spaces)
#     neighbor_data = line.split()
#     neighbor = neighbor_data[0]
#     pfx_rcd = neighbor_data[-1]
#     print(f"Neighbor: {neighbor} Prefix Received: {pfx_rcd}")

# print('end of first code')



##########Better Method #########

lines = output.strip().splitlines()
#print(lines)



matching_interfaces = []

# Iterate over each line after the header
for line in lines[18:33]:  # Skip the first three lines (header)
    parts = line.split()
    #print (parts)
    neighbor = parts[0]
    pfx_rcd = parts[-1]
    print(f"Neighbor: {neighbor} Prefix Received: {pfx_rcd}")
# Out:
# Neighbor: 100.250.104.99 Prefix Received: 0
# Neighbor: 100.250.202.99 Prefix Received: 0
# Neighbor: 100.250.204.99 Prefix Received: 0
# Neighbor: 100.250.208.99 Prefix Received: 1691
# Neighbor: 100.250.209.99 Prefix Received: 1691
# Neighbor: 101.52.0.0 Prefix Received: 100
# Neighbor: 101.52.0.2 Prefix Received: 100
# Neighbor: 101.62.0.0 Prefix Received: 39950
# Neighbor: 101.62.0.2 Prefix Received: 78440
# Neighbor: 101.62.0.4 Prefix Received: 39950
# Neighbor: 101.62.0.6 Prefix Received: 78440
# Neighbor: 101.62.0.8 Prefix Received: 78440
# Neighbor: 101.62.0.10 Prefix Received: 39950
# Neighbor: 101.62.0.12 Prefix Received: 39950
# Neighbor: 101.62.0.14 Prefix Received: 62096

# %%
#snmp parsing

import re
output = """
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.0 = Counter64: 1692787
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.1 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.2 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.3 = Counter64: 260449646
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.4 = Counter64: 260446553
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.5 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.6 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.7 = Counter64: 0
"""

# # TC0_SNMP = 0
# # TC3_SNMP = 0
# # TC4_SNMP = 0
# # # Iterate over each line in the output
# # for line in output.splitlines():
# #     # Extract the OID and value using regular expressions
# #     match = re.search(r"(.*) = Counter64: (\d+)", line)
# #     if match:
# #         oid, value = match.groups()

# #         # Check if the OID matches the desired ones
# #         if oid.endswith(".0"):
# #             TC0_SNMP = int(value)
# #         elif oid.endswith(".3"):
# #             TC3_SNMP = int(value)
# #         elif oid.endswith(".4"):
# #             TC4_SNMP = int(value)

# # # Print the parsed values
# # print(f"TC3_SNMP: {TC0_SNMP}")
# # print(f"TC4_SNMP: {TC3_SNMP}")
# # print(f"TC4_SNMP: {TC4_SNMP}")


# TC0_SNMP = 0
# TC3_SNMP = 0
# TC4_SNMP = 0

# # Iterate over each line in the output
# for line in output.splitlines():
#   # Split the line by whitespace (considering multiple spaces)
#   parts = line.split()
#   #print(parts)

#   # Check for valid format (at least 6 parts and "Counter64:")
#   if len(parts) >= 4 and parts[2] == "Counter64:":
#     oid = parts[0]  # Assuming OID is the first part
#     value = int(parts[3])  # Assuming value is the 6th part

#     # Check OID suffix and assign value
#     if oid.endswith(".0"):
#       TC0_SNMP = value
#     elif oid.endswith(".3"):
#       TC3_SNMP = value
#     elif oid.endswith(".4"):
#       TC4_SNMP = value

# # Print the parsed values
# print(f"TC0_SNMP: {TC0_SNMP}")
# print(f"TC3_SNMP: {TC3_SNMP}")
# print(f"TC4_SNMP: {TC4_SNMP}")




# ################################################# Better Method ##########################################

# lines = output.strip().splitlines()


# for line in lines:
#   parts = line.split()
#   #print(parts)
#   snmp_id = parts[0]
#   oid = parts [-1]

#   if snmp_id.endswith(".0"):
#     TC0_SNMP = oid
#     print(f"TC0_SNMP: {TC0_SNMP}")
#   elif snmp_id.endswith(".3"):
#     TC3_SNMP = oid
#     print(f"TC3_SNMP: {TC3_SNMP}")
#   elif snmp_id.endswith(".4"):
#     TC4_SNMP = oid
#     print(f"TC4_SNMP: {TC4_SNMP}")



# Output string
output = """
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.0 = Counter64: 1692787
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.1 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.2 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.3 = Counter64: 260449646
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.4 = Counter64: 260446553
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.5 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.6 = Counter64: 0
SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.7 = Counter64: 0
"""

# Initialize an empty dictionary to store the results
result_dict = {}

# Split the output into lines
lines = output.strip().splitlines()

# Iterate through each line
for line in lines:
    # Split each line into key and value parts
    key, value = line.split(" = Counter64: ")
    print(key)
    print(value)
    
    # Clean up any extra spaces and add the key-value pair to the dictionary
    result_dict[key.strip()] = int(value.strip())

# Print the resulting dictionary
print(result_dict)
# Out:
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.0
# 1692787
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.1
# 0
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.2
# 0
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.3
# 260449646
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.4
# 260446553
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.5
# 0
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.6
# 0
# SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.7
# 0
# {'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.0': 1692787, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.1': 0, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.2': 0, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.3': 260449646, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.4': 260446553, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.5': 0, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.6': 0, 'SNMPv2-SMI::enterprises.9.9.813.1.2.1.3.1190.7': 0}
